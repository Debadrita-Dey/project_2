# %%
import pandas as pd
import numpy as np
path= r"C:\Users\DELL\Desktop\ml\Cellphone.xlsx"
df=pd.read_excel(path)
print(df.head())
# Out:
#    Product_id  Price  Sale  weight  resoloution  ppi  cpu core  cpu freq  \
# 0         203   2357    10   135.0          5.2  424         8      1.35
# 1         880   1749    10   125.0          4.0  233         2      1.30
# 2          40   1916    10   110.0          4.7  312         4      1.20
# 3          99   1315    11   118.5          4.0  233         2      1.30
# 4         880   1749    11   125.0          4.0  233         2      1.30
#
#    internal mem    ram  RearCam  Front_Cam  battery  thickness
# 0          16.0  3.000    13.00        8.0     2610        7.4
# 1           4.0  1.000     3.15        0.0     1700        9.9
# 2           8.0  1.500    13.00        5.0     2000        7.6
# 3           4.0  0.512     3.15        0.0     1400       11.0
# 4           4.0  1.000     3.15        0.0     1700        9.9

# %%
df.isnull().sum()
# Out:
# Product_id      0
# Price           0
# Sale            0
# weight          0
# resoloution     0
# ppi             0
# cpu core        0
# cpu freq        0
# internal mem    0
# ram             0
# RearCam         0
# Front_Cam       0
# battery         0
# thickness       0
# dtype: int64

# %%
df.columns=df.columns.str.lower()
df.columns
# Out:
# Index(['product_id', 'price', 'sale', 'weight', 'resoloution', 'ppi',
#        'cpu core', 'cpu freq', 'internal mem', 'ram', 'rearcam', 'front_cam',
#        'battery', 'thickness'],
#       dtype='object')

# %%
df.columns=df.columns.str.replace(' ','_')
df.columns
# Out:
# Index(['product_id', 'price', 'sale', 'weight', 'resoloution', 'ppi',
#        'cpu_core', 'cpu_freq', 'internal_mem', 'ram', 'rearcam', 'front_cam',
#        'battery', 'thickness'],
#       dtype='object')

# %%
df.head()
# Out:
#    product_id  price  sale  weight  resoloution  ppi  cpu_core  cpu_freq  \
# 0         203   2357    10   135.0          5.2  424         8      1.35
# 1         880   1749    10   125.0          4.0  233         2      1.30
# 2          40   1916    10   110.0          4.7  312         4      1.20
# 3          99   1315    11   118.5          4.0  233         2      1.30
# 4         880   1749    11   125.0          4.0  233         2      1.30
#
#    internal_mem    ram  rearcam  front_cam  battery  thickness
# 0          16.0  3.000    13.00        8.0     2610        7.4
# 1           4.0  1.000     3.15        0.0     1700        9.9
# 2           8.0  1.500    13.00        5.0     2000        7.6
# 3           4.0  0.512     3.15        0.0     1400       11.0
# 4           4.0  1.000     3.15        0.0     1700        9.9

# %%
df.duplicated()  # Returns a boolean series indicating duplicate rows
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 156    False
# 157    False
# 158    False
# 159    False
# 160    False
# Length: 161, dtype: bool

# %%
df.columns = df.columns.str.strip()
df.columns
# Out:
# Index(['product_id', 'price', 'sale', 'weight', 'resoloution', 'ppi',
#        'cpu_core', 'cpu_freq', 'internal_mem', 'ram', 'rearcam', 'front_cam',
#        'battery', 'thickness'],
#       dtype='object')

# %%
df['price_per_ram'] = df['price'] / df['ram']
df.head()
# Out:
#    product_id  price  sale  weight  resoloution  ppi  cpu_core  cpu_freq  \
# 0         203   2357    10   135.0          5.2  424         8      1.35
# 1         880   1749    10   125.0          4.0  233         2      1.30
# 2          40   1916    10   110.0          4.7  312         4      1.20
# 3          99   1315    11   118.5          4.0  233         2      1.30
# 4         880   1749    11   125.0          4.0  233         2      1.30
#
#    internal_mem    ram  rearcam  front_cam  battery  thickness  price_per_ram
# 0          16.0  3.000    13.00        8.0     2610        7.4     785.666667
# 1           4.0  1.000     3.15        0.0     1700        9.9    1749.000000
# 2           8.0  1.500    13.00        5.0     2000        7.6    1277.333333
# 3           4.0  0.512     3.15        0.0     1400       11.0    2568.359375
# 4           4.0  1.000     3.15        0.0     1700        9.9    1749.000000

# %%
df['cpu_power'] = df['cpu_core'] * df['cpu_freq']
df.head()
# Out:
#    product_id  price  sale  weight  resoloution  ppi  cpu_core  cpu_freq  \
# 0         203   2357    10   135.0          5.2  424         8      1.35
# 1         880   1749    10   125.0          4.0  233         2      1.30
# 2          40   1916    10   110.0          4.7  312         4      1.20
# 3          99   1315    11   118.5          4.0  233         2      1.30
# 4         880   1749    11   125.0          4.0  233         2      1.30
#
#    internal_mem    ram  rearcam  front_cam  battery  thickness  price_per_ram  \
# 0          16.0  3.000    13.00        8.0     2610        7.4     785.666667
# 1           4.0  1.000     3.15        0.0     1700        9.9    1749.000000
# 2           8.0  1.500    13.00        5.0     2000        7.6    1277.333333
# 3           4.0  0.512     3.15        0.0     1400       11.0    2568.359375
# 4           4.0  1.000     3.15        0.0     1700        9.9    1749.000000
#
#    cpu_power
# 0       10.8
# 1        2.6
# 2        4.8
# ...

# %%
bins = [0, 10000, 30000, 50000, float('inf')]
labels = ['budget', 'mid_range', 'premium', 'high_end']
df['price_category'] = pd.cut(df['price'], bins=bins, labels=labels)
df.iloc[30:50]
# Out:
#     product_id  price  sale  weight  resoloution  ppi  cpu_core  cpu_freq  \
# 30         187   2258    26   150.0          5.0  441         4     2.300
# 31         990   2977    26   152.0          5.1  577         8     2.300
# 32        1145   3316    26   144.0          5.2  428         8     1.750
# 33        1020   2654    30   151.0          5.7  386         8     1.550
# 34        1339   1421    31   120.0          4.0  233         2     1.000
# 35        1020   2654    32   151.0          5.7  386         8     1.550
# 36         104   1942    34   139.2          4.7  469         4     2.150
# 37         662   2124    35   489.0         10.1  224         4     2.260
# 38         575   1777    36   174.0          5.5  178         4     1.300
# 39         860   2392    36   147.0          5.2  282         8     1.400
# 40         662   2124    37   489.0         10.1  224         4     2.260
# 41         907   2087    37   147.0          5.0  294         4     1.300
# ...

# %%
#df=df.drop(columns=['price_category'],inplace=True)
df.head()
# Out:
#    product_id  price  sale  weight  resoloution  ppi  cpu_core  cpu_freq  \
# 0         203   2357    10   135.0          5.2  424         8      1.35
# 1         880   1749    10   125.0          4.0  233         2      1.30
# 2          40   1916    10   110.0          4.7  312         4      1.20
# 3          99   1315    11   118.5          4.0  233         2      1.30
# 4         880   1749    11   125.0          4.0  233         2      1.30
#
#    internal_mem    ram  rearcam  front_cam  battery  thickness  price_per_ram  \
# 0          16.0  3.000    13.00        8.0     2610        7.4     785.666667
# 1           4.0  1.000     3.15        0.0     1700        9.9    1749.000000
# 2           8.0  1.500    13.00        5.0     2000        7.6    1277.333333
# 3           4.0  0.512     3.15        0.0     1400       11.0    2568.359375
# 4           4.0  1.000     3.15        0.0     1700        9.9    1749.000000
#
#    cpu_power
# 0       10.8
# 1        2.6
# 2        4.8
# ...

# %%
df.to_excel(r'C:\Users\DELL\Desktop\ml.xlsx', index=False)
